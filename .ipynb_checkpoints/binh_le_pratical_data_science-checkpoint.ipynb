# %%
import urllib2 
initial_filename = 'datasets.csv' # initial file provided from the course

import pandas as pd    
emails= pd.read_csv(initial_filename)

import numpy as np

# %%
#quickly check the data
emails
# Out:
#                 send_date            open_date  open     browser  is_mobile  \
# 0     2018-04-07 23:40:57  1970-01-01 10:00:00     0         NaN        NaN
# 1     2018-04-08 13:02:04  2018-04-09 11:58:26     4     Firefox        0.0
# 2     2018-04-09 04:47:11  2018-04-09 04:49:54     2     Firefox        0.0
# 3     2018-04-09 15:13:09  2018-04-09 23:25:28     1     Firefox        0.0
# 4     2018-04-10 00:21:37  1970-01-01 10:00:00     0         NaN        NaN
# 5     2018-04-10 00:26:45  2018-04-10 00:26:55     1     Firefox        0.0
# 6     2018-04-03 23:59:48  2018-04-16 19:37:43     2     Firefox        0.0
# 7     2018-04-03 23:54:27  2018-04-09 00:15:32     1     Outlook        0.0
# 8     2018-04-09 14:52:15  2018-04-12 20:52:34     1     Firefox        0.0
# 9     2018-04-04 13:05:24  2018-04-06 03:48:15     5     Firefox        0.0
# 10    2018-04-09 07:59:43  1970-01-01 10:00:00     0         NaN        NaN
# ...
